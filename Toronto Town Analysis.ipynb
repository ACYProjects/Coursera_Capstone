# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# %% [markdown]
# # Wikipedia Page

# %%
#Import Data
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0  M1A      Not assigned      Not assigned
# 1  M2A      Not assigned      Not assigned
# 2  M3A      North York        Parkwoods
# 3  M4A      North York        Victoria Village
# 4  M5A      Downtown Toronto  Harbourfront

# %%
#Filter Borough
df = df[df['Borough']!='Not assigned']
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2  M3A      North York        Parkwoods
# 3  M4A      North York        Victoria Village
# 4  M5A      Downtown Toronto  Harbourfront
# 5  M6A      North York        Lawrence Heights
# 6  M6A      North York        Lawrence Manor

# %%
#Neighboorhood Grouping
df2 = df.groupby(['Postcode','Borough']).Neighbourhood.agg([('count', 'count'), ('Neighbourhood', ', '.join)])

df2['Postcode']= df2.index.get_level_values(level=0)
df2['Borough']= df2.index.get_level_values(level=1)

del df2['count']
del df

s = pd.Series(np.arange(0,len(df2)))
df2=df2.set_index(s)

df2.head()
# Out:
#                             Neighbourhood Postcode      Borough
# 0  Rouge, Malvern                          M1B      Scarborough
# 1  Highland Creek, Rouge Hill, Port Union  M1C      Scarborough
# 2  Guildwood, Morningside, West Hill       M1E      Scarborough
# 3  Woburn                                  M1G      Scarborough
# 4  Cedarbrae                               M1H      Scarborough

# %%
#Import Town coordinates
Coor_Town = pd.read_csv('http://cocl.us/Geospatial_data')
Coor_Town.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0  M1B         43.806686 -79.194353
# 1  M1C         43.784535 -79.160497
# 2  M1E         43.763573 -79.188711
# 3  M1G         43.770992 -79.216917
# 4  M1H         43.773136 -79.239476

# %%
df3 = pd.merge(df2, Coor_Town, left_on='Postcode', right_on='Postal Code', how='left')
del df3['Postal Code']
del df2
del Coor_Town
df3.head()
# Out:
#                             Neighbourhood Postcode      Borough   Latitude  \
# 0  Rouge, Malvern                          M1B      Scarborough  43.806686
# 1  Highland Creek, Rouge Hill, Port Union  M1C      Scarborough  43.784535
# 2  Guildwood, Morningside, West Hill       M1E      Scarborough  43.763573
# 3  Woburn                                  M1G      Scarborough  43.770992
# 4  Cedarbrae                               M1H      Scarborough  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# # Analysis using Foursquare

# %%
#Credential params
CLIENT_ID = '2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX' # your Foursquare ID
CLIENT_SECRET = 'MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ' # your Foursquare Secret
VERSION = '20200201'
LIMIT = 30

# %%
address = "Toronto, Canada"

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
#Art related, within 3000 mts
search_query = 'Art'
radius = 3000

#Define URL, with params
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX&client_secret=MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ&ll=43.653963,-79.387207&v=20200201&query=Art&radius=3000&limit=30'

# %%
#Get Json
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e59bfa70be7b4001b2ac7ea'},
#  'response': {'venues': [{'id': '4ad4c05ef964a520daf620e3',
#     'name': 'Art Gallery of Ontario',
#     'location': {'address': '317 Dundas St W',
#      'crossStreet': 'at Beverley St',
#      'lat': 43.654002860337386,
#      'lng': -79.39292172707437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654002860337386,
#        'lng': -79.39292172707437}],
#      'distance': 460,
#      'postalCode': 'M5T 1G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['317 Dundas St W (at Beverley St)',
#       'Toronto ON M5T 1G4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '33853777'},
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4ad4c064f964a52065f820e3',
#     'name': 'Ontario College of Art and Design University (OCADU)',
#     'location': {'address': '100 McCaul St',
#      'crossStreet': 'at Dundas St W',
#      'lat': 43.65280251171013,
#      'lng': -79.3910743699992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65280251171013,
#        'lng': -79.3910743699992}],
#      'distance': 337,
#      'postalCode': 'M5T 1W1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 McCaul St (at Dundas St W)',
#       'Toronto ON M5T 1W1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ae941735',
#       'name': 'University',
#       'pluralName': 'Universities',
#       'shortName': 'University',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4adf3c01f964a5208f7821e3',
#     'name': 'Aboveground Art Supplies',
#     'location': {'address': '74 McCaul St',
#      'crossStreet': 'Dundas St.',
#      'lat': 43.652645648070006,
#      'lng': -79.3909251764317,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652645648070006,
#        'lng': -79.3909251764317}],
#      'distance': 333,
#      'postalCode': 'M5T 3K2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['74 McCaul St (Dundas St.)',
#       'Toronto ON M5T 3K2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4f64f2c0e4b0c7552d4dbfbf',
#     'name': 'CMU College of Makeup Art & Design',
#     'location': {'address': '110 Lombard St.',
#      'lat': 43.65251631855119,
#      'lng': -79.37325153352174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65251631855119,
#        'lng': -79.37325153352174}],
#      'distance': 1135,
#      'postalCode': 'M5C 1M3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Lombard St.', 'Toronto ON M5C 1M3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4f0b5bfae4b06fab1c0478f2',
#     'name': 'Department of Art',
#     'location': {'address': 'Room 6036 Sidney Smith Hall 100 St. George Street',
#      'crossStreet': 'Wilcocks Street',
#      'lat': 43.66300780461368,
#      'lng': -79.39879315884255,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66300780461368,
#        'lng': -79.39879315884255}],
#      'distance': 1372,
#      'postalCode': 'M5S3g3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Room 6036 Sidney Smith Hall 100 St. George Street (Wilcocks Street)',
#       'Toronto ON M5S3g3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d199941735',
#       'name': 'College Arts Building',
#       'pluralName': 'College Arts Buildings',
#       'shortName': 'Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4b6b189cf964a52089f22be3',
#     'name': "Curry's Art Store Ltd.",
#     'location': {'address': '490 Yonge St.',
#      'crossStreet': 'At Grosvenor',
#      'lat': 43.66283810530193,
#      'lng': -79.38373201352064,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66283810530193,
#        'lng': -79.38373201352064}],
#      'distance': 1026,
#      'postalCode': 'M4Y 1X5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['490 Yonge St. (At Grosvenor)',
#       'Toronto ON M4Y 1X5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4b76f1baf964a5200c6d2ee3',
#     'name': 'Toronto School of Art (TSA)',
#     'location': {'address': '410 Adelaide Street West  3rd Floor',
#      'crossStreet': 'Spadina',
#      'lat': 43.646599947509415,
#      'lng': -79.39659775889797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646599947509415,
#        'lng': -79.39659775889797}],
#      'distance': 1115,
#      'postalCode': 'M5V 1S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['410 Adelaide Street West  3rd Floor (Spadina)',
#       'Toronto ON M5V 1S8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4d8a79ae6ce6a35de4a26142',
#     'name': 'University College Art Centre',
#     'location': {'crossStreet': 'King College Circle and Tower Rd',
#      'lat': 43.663962206170915,
#      'lng': -79.39538469518658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.663962206170915,
#        'lng': -79.39538469518658}],
#      'distance': 1293,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['King College Circle and Tower Rd',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4ee276d2e4b087894c6e1e8d',
#     'name': 'Cabbagetown Community Art Centre',
#     'location': {'address': '422 Parliament',
#      'crossStreet': 'Carlton',
#      'lat': 43.66132776798641,
#      'lng': -79.37049910581379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66132776798641,
#        'lng': -79.37049910581379}],
#      'distance': 1575,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['422 Parliament (Carlton)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a2941735',
#       'name': 'Community College',
#       'pluralName': 'Community Colleges',
#       'shortName': 'Community College',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/communitycollege_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4ae23c71f964a5202d8c21e3',
#     'name': 'Arts & Letters Club',
#     'location': {'address': '14 Elm Street',
#      'crossStreet': 'Elm & Yonge',
#      'lat': 43.65777388456869,
#      'lng': -79.38244978400367,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65777388456869,
#        'lng': -79.38244978400367}],
#      'distance': 571,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['14 Elm Street (Elm & Yonge)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4dff6f15e4cdf724607880c2',
#     'name': 'Art Bike Installation',
#     'location': {'lat': 43.65504131399523,
#      'lng': -79.38868284945416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65504131399523,
#        'lng': -79.38868284945416}],
#      'distance': 168,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4ae47067f964a520989a21e3',
#     'name': 'Art Square Gallery & Cafe',
#     'location': {'address': '334 Dundas St West',
#      'lat': 43.65422714439051,
#      'lng': -79.39253595754614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65422714439051,
#        'lng': -79.39253595754614}],
#      'distance': 430,
#      'postalCode': 'M5T 1G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['334 Dundas St West',
#       'Toronto ON M5T 1G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4fca7001e4b00e68465ddd13',
#     'name': 'Art Framing N Copy Co.',
#     'location': {'address': '189 Dundas St. W',
#      'lat': 43.65545281866891,
#      'lng': -79.38689047699962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65545281866891,
#        'lng': -79.38689047699962}],
#      'distance': 167,
#      'postalCode': 'M5G 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['189 Dundas St. W', 'Toronto ON M5G 1C7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '581b1958b293f71968399461',
#     'name': 'Art of Ciel',
#     'location': {'address': '100 Mccaul Street',
#      'lat': 43.65273914851638,
#      'lng': -79.39157500863074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65273914851638,
#        'lng': -79.39157500863074}],
#      'distance': 377,
#      'postalCode': 'M5T 1W1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Mccaul Street',
#       'Toronto ON M5T 1W1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '51cdc245e4b05a0d9168811c',
#     'name': 'Rosy Nails & Art Design',
#     'location': {'lat': 43.65559,
#      'lng': -79.38437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65559,
#        'lng': -79.38437}],
#      'distance': 291,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4e038c55e4cdbd9a5177e3b4',
#     'name': 'OCADU Faculty Of Art Office',
#     'location': {'address': '100 McCaul',
#      'lat': 43.653357,
#      'lng': -79.391256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653357,
#        'lng': -79.391256}],
#      'distance': 333,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 McCaul', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '593e4362d48ec17c5a58be86',
#     'name': 'Radio Art',
#     'location': {'lat': 43.65334792524734,
#      'lng': -79.38262432850024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65334792524734,
#        'lng': -79.38262432850024}],
#      'distance': 375,
#      'postalCode': 'M4V 1E5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M4V 1E5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4c389c573849c928c4bdbfb1',
#     'name': 'Toronto Outdoor Art Exhibition',
#     'location': {'address': 'Nathan Phillips Square',
#      'lat': 43.65256548970664,
#      'lng': -79.38330012960093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65256548970664,
#        'lng': -79.38330012960093}],
#      'distance': 351,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'Ont',
#      'country': 'Canada',
#      'formattedAddress': ['Nathan Phillips Square', 'Toronto Ont', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '521b957f11d2c8ababfc94e8',
#     'name': 'Consignor Canadian Fine Art',
#     'location': {'address': '326 Dundas Street West',
#      'lat': 43.654307,
#      'lng': -79.392269,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654307,
#        'lng': -79.392269}],
#      'distance': 409,
#      'postalCode': 'M5T 1G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['326 Dundas Street West',
#       'Toronto ON M5T 1G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '68363829'},
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4bc0a9a274a9a5938261d0f6',
#     'name': 'Art Condos',
#     'location': {'address': '44 Dovercourt Road',
#      'lat': 43.64151129204229,
#      'lng': -79.4215606685209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64151129204229,
#        'lng': -79.4215606685209}],
#      'distance': 3094,
#      'postalCode': 'M6J 1H3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['44 Dovercourt Road',
#       'Toronto ON M6J 1H3',
#       'Canada']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4f860ed6e4b03fee372660af',
#     'name': 'Art One',
#     'location': {'lat': 43.649512,
#      'lng': -79.382797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649512,
#        'lng': -79.382797}],
#      'distance': 609,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '5dab78d240edfe0008646ab4',
#     'name': 'Thomson Collection Of Canadian Art',
#     'location': {'address': 'AGO L2',
#      'lat': 43.653854,
#      'lng': -79.39257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653854,
#        'lng': -79.39257}],
#      'distance': 432,
#      'postalCode': 'M5T 1G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['AGO L2', 'Toronto ON M5T 1G4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4ee14f442c5b955eefc13a00',
#     'name': 'Project: Art',
#     'location': {'address': '230 Queen W',
#      'lat': 43.65006823814529,
#      'lng': -79.39016180548623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65006823814529,
#        'lng': -79.39016180548623}],
#      'distance': 494,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['230 Queen W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '573cb4cf498eec996e9cfb1d',
#     'name': 'Peter Triantos Art Gallery',
#     'location': {'address': '1042 Bathurst St',
#      'lat': 43.671592,
#      'lng': -79.413765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.671592,
#        'lng': -79.413765}],
#      'distance': 2902,
#      'postalCode': 'M5R 3G7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1042 Bathurst St', 'Toronto ON M5R 3G7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4c89092649ddef3bcedf7b70',
#     'name': 'Absolut St. Art',
#     'location': {'address': '22 Sheppard St',
#      'crossStreet': 'Bay and Adelaide',
#      'lat': 43.649877,
#      'lng': -79.382775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649877,
#        'lng': -79.382775}],
#      'distance': 578,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['22 Sheppard St (Bay and Adelaide)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4e9eccdfb6340e3e34b62396',
#     'name': 'CATIE - The Art and Science of Knowledge Exchange',
#     'location': {'lat': 43.658343,
#      'lng': -79.383163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658343,
#        'lng': -79.383163}],
#      'distance': 586,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ff931735',
#       'name': 'Convention Center',
#       'pluralName': 'Convention Centers',
#       'shortName': 'Convention Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '54929a7e498ea3488d74417d',
#     'name': 'Sheldon Rose Art Consultant',
#     'location': {'lat': 43.64840449030172,
#      'lng': -79.38534021377563,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64840449030172,
#        'lng': -79.38534021377563}],
#      'distance': 636,
#      'postalCode': 'M6G 1N5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M6G 1N5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '5cde837bf870fd002c5273eb',
#     'name': 'Financial Science and Art',
#     'location': {'lat': 43.6548421,
#      'lng': -79.3792015,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6548421,
#        'lng': -79.3792015}],
#      'distance': 652,
#      'postalCode': 'M5B 2R6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5B 2R6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '5585b9d1498e657b30cd0631',
#     'name': 'Coldstream Fine Art',
#     'location': {'lat': 43.646108509046776,
#      'lng': -79.39574204001536,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646108509046776,
#        'lng': -79.39574204001536}],
#      'distance': 1112,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False},
#    {'id': '4bc7a9eb92b376b0f035503a',
#     'name': '504 Wellington Art Galley',
#     'location': {'lat': 43.647848,
#      'lng': -79.390066,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647848,
#        'lng': -79.390066}],
#      'distance': 718,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1582940072',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id  \
# 0  4ad4c05ef964a520daf620e3
# 1  4ad4c064f964a52065f820e3
# 2  4adf3c01f964a5208f7821e3
# 3  4f64f2c0e4b0c7552d4dbfbf
# 4  4f0b5bfae4b06fab1c0478f2
#
#                                                    name  \
# 0  Art Gallery of Ontario
# 1  Ontario College of Art and Design University (OCADU)
# 2  Aboveground Art Supplies
# 3  CMU College of Makeup Art & Design
# 4  Department of Art
#
#                                                                                                                                                                                                                                                         categories  \
# 0  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'Art Gallery', 'pluralName': 'Art Galleries', 'shortName': 'Art Gallery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d1ae941735', 'name': 'University', 'pluralName': 'Universities', 'shortName': 'University', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4bf58dd8d48988d127951735', 'name': 'Arts & Crafts Store', 'pluralName': 'Arts & Crafts Stores', 'shortName': 'Arts & Crafts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4bf58dd8d48988d13b941735', 'name': 'School', 'pluralName': 'Schools', 'shortName': 'School', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d199941735', 'name': 'College Arts Building', 'pluralName': 'College Arts Buildings', 'shortName': 'Arts', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_', 'suffix': '.png'}, 'primary': True}]
#
#      referralId  hasPerk                                   location.address  \
# 0  v-1582940072  False    317 Dundas St W
# 1  v-1582940072  False    100 McCaul St
# 2  v-1582940072  False    74 McCaul St
# 3  v-1582940072  False    110 Lombard St.
# 4  v-1582940072  False    Room 6036 Sidney Smith Hall 100 St. George Street
#
#   location.crossStreet  location.lat  location.lng  \
# 0  at Beverley St       43.654003    -79.392922
# 1  at Dundas St W       43.652803    -79.391074
# 2  Dundas St.           43.652646    -79.390925
# 3  NaN                  43.652516    -79.373252
# 4  Wilcocks Street      43.663008    -79.398793
#
#                                                         location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 43.654002860337386, 'lng': -79.39292172707437}]
# 1  [{'label': 'display', 'lat': 43.65280251171013, 'lng': -79.3910743699992}]
# 2  [{'label': 'display', 'lat': 43.652645648070006, 'lng': -79.3909251764317}]
# 3  [{'label': 'display', 'lat': 43.65251631855119, 'lng': -79.37325153352174}]
# 4  [{'label': 'display', 'lat': 43.66300780461368, 'lng': -79.39879315884255}]
#
#    location.distance location.postalCode location.cc location.city  \
# 0  460                M5T 1G4             CA          Toronto
# 1  337                M5T 1W1             CA          Toronto
# 2  333                M5T 3K2             CA          Toronto
# 3  1135               M5C 1M3             CA          Toronto
# 4  1372               M5S3g3              CA          Toronto
#
#   location.state location.country  \
# 0  ON             Canada
# 1  ON             Canada
# 2  ON             Canada
# 3  ON             Canada
# 4  ON             Canada
#
#                                                                           location.formattedAddress  \
# 0  [317 Dundas St W (at Beverley St), Toronto ON M5T 1G4, Canada]
# 1  [100 McCaul St (at Dundas St W), Toronto ON M5T 1W1, Canada]
# 2  [74 McCaul St (Dundas St.), Toronto ON M5T 3K2, Canada]
# 3  [110 Lombard St., Toronto ON M5C 1M3, Canada]
# 4  [Room 6036 Sidney Smith Hall 100 St. George Street (Wilcocks Street), Toronto ON M5S3g3, Canada]
#
#   venuePage.id
# 0  33853777
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                                                    name  \
# 0  Art Gallery of Ontario
# 1  Ontario College of Art and Design University (OCADU)
# 2  Aboveground Art Supplies
# 3  CMU College of Makeup Art & Design
# 4  Department of Art
#
#               categories                                            address  \
# 0  Art Gallery            317 Dundas St W
# 1  University             100 McCaul St
# 2  Arts & Crafts Store    74 McCaul St
# 3  School                 110 Lombard St.
# 4  College Arts Building  Room 6036 Sidney Smith Hall 100 St. George Street
#
#        crossStreet        lat        lng  \
# 0  at Beverley St   43.654003 -79.392922
# 1  at Dundas St W   43.652803 -79.391074
# 2  Dundas St.       43.652646 -79.390925
# 3  NaN              43.652516 -79.373252
# 4  Wilcocks Street  43.663008 -79.398793
#
#                                                                  labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 43.654002860337386, 'lng': -79.39292172707437}]
# 1  [{'label': 'display', 'lat': 43.65280251171013, 'lng': -79.3910743699992}]
# 2  [{'label': 'display', 'lat': 43.652645648070006, 'lng': -79.3909251764317}]
# 3  [{'label': 'display', 'lat': 43.65251631855119, 'lng': -79.37325153352174}]
# 4  [{'label': 'display', 'lat': 43.66300780461368, 'lng': -79.39879315884255}]
#
#    distance postalCode  cc     city state country  \
# 0  460       M5T 1G4    CA  Toronto  ON    Canada
# 1  337       M5T 1W1    CA  Toronto  ON    Canada
# 2  333       M5T 3K2    CA  Toronto  ON    Canada
# 3  1135      M5C 1M3    CA  Toronto  ON    Canada
# 4  1372      M5S3g3     CA  Toronto  ON    Canada
#
#                                                                                    formattedAddress  \
# 0  [317 Dundas St W (at Beverley St), Toronto ON M5T 1G4, Canada]
# 1  [100 McCaul St (at Dundas St W), Toronto ON M5T 1W1, Canada]
# 2  [74 McCaul St (Dundas St.), Toronto ON M5T 3K2, Canada]
# 3  [110 Lombard St., Toronto ON M5C 1M3, Canada]
# 4  [Room 6036 Sidney Smith Hall 100 St. George Street (Wilcocks Street), Toronto ON M5S3g3, Canada]
#
#                          id
# 0  4ad4c05ef964a520daf620e3
# 1  4ad4c064f964a52065f820e3
# 2  4adf3c01f964a5208f7821e3
# 3  4f64f2c0e4b0c7552d4dbfbf
# 4  4f0b5bfae4b06fab1c0478f2

# %%
#Names
dataframe_filtered.name.head()
# Out:
# 0    Art Gallery of Ontario
# 1    Ontario College of Art and Design University (OCADU)
# 2    Aboveground Art Supplies
# 3    CMU College of Makeup Art & Design
# 4    Department of Art
# Name: name, dtype: object

# %%
#29 Venues within radius
#Visualization
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Center of Toronto
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Toronto Centre',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Explore a given venue
#https://api.foursquare.com/v2/venues/VENUE_ID?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=VERSION

venue_id = '4ad4c064f964a52065f820e3' #Ontario College of Art and Design
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad4c064f964a52065f820e3?client_id=2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX&client_secret=MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ&v=20200201'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'venueRatingBlacklisted', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad4c064f964a52065f820e3',
#  'name': 'Ontario College of Art and Design University (OCADU)',
#  'contact': {'phone': '4169776000',
#   'formattedPhone': '(416) 977-6000',
#   'twitter': 'ocad'},
#  'location': {'address': '100 McCaul St',
#   'crossStreet': 'at Dundas St W',
#   'lat': 43.65280251171013,
#   'lng': -79.3910743699992,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.65280251171013,
#     'lng': -79.3910743699992}],
#   'postalCode': 'M5T 1W1',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['100 McCaul St (at Dundas St W)',
#    'Toronto ON M5T 1W1',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/ontario-college-of-art-and-design-university-ocadu/4ad4c064f964a52065f820e3',
#  'categories': [{'id': '4bf58dd8d48988d1ae941735',
#    'name': 'University',
#    'pluralName': 'Universities',
#    'shortName': 'University',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d1e2931735',
#    'name': 'Art Gallery',
#    'pluralName': 'Art Galleries',
#    'shortName': 'Art Gallery',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#     'suffix': '.png'}},
#   {'id': '4bf58dd8d48988d1a8941735',
#    'name': 'General College & University',
#    'pluralName': 'General Colleges & Universities',
#    'shortName': 'Education',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 20},
#  'url': 'http://www.ocadu.ca',
#  'likes': {'count': 105,
#   'groups': [{'type': 'others', 'count': 105, 'items': []}],
#   'summary': '105 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 8.3,
#  'ratingColor': '73CF42',
#  'ratingSignals': 128,
#  'venueRatingBlacklisted': True,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 383,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 383,
#     'items': [{'id': '50e6f769e4b06958b1fdf7a6',
#       'createdAt': 1357313897,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/63159_xLOrOT5wltKh0G4gLdw63hExOVU3JgvVET7jDik4NlE.jpg',
#       'width': 612,
#       'height': 612,
#       'user': {'id': '63159',
#        'firstName': 'nik',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/ZIIIPGCR22P0H3R2.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': 'OCAD University is Canada’s “university of the imagination.” The University, founded in 1876, is dedicated to art and design education, practice and research and to knowledge and invention across a wide range of disciplines.',
#  'page': {'pageInfo': {'description': "OCAD University is Canada's University of  Imagination! Visit us hear to find out about our free lectures, art and design exhibitions and opportunities to meet our students and faculty.",
#    'banner': 'https://is1.4sqi.net/userpix/CM2GHNOHW0ZEJXDL.jpg',
#    'links': {'count': 1, 'items': [{'url': 'http://www.ocadu.ca'}]}},
#   'user': {'id': '33776072',
#    'firstName': 'OCAD University',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/ZCXJCBGFFH4JOC4V.jpg'},
#    'type': 'chain',
#    'tips': {'count': 4},
#    'lists': {'groups': [{'type': 'created', 'count': 4, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1255456868,
#  'tips': {'count': 20,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 20,
#     'items': [{'id': '4e42f642d4c0cc806638ae92',
#       'createdAt': 1313011266,
#       'text': "Advice for attending this school; take advantage of everything you can get your grubby little fingers on. All your resources are here in one spot & you'll be hard-pressed to find them elsewhere.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4e42f642d4c0cc806638ae92',
#       'lang': 'en',
#       'likes': {'count': 5,
#        'groups': [{'type': 'others',
#          'count': 5,
#          'items': [{'id': '98789447',
#            'firstName': 'Michelle',
#            'lastName': 'S',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_girl.png',
#             'default': True}},
#           {'id': '30601921',
#            'firstName': 'Zee',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/ICXTPHCXSJOOIWPZ.jpg'}},
#           {'id': '70367358',
#            'firstName': 'Tony',
#            'lastName': 'K',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/V3KIHVCG5XRDQLO1.jpg'}},
#           {'id': '215528',
#            'firstName': 'Mike',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/ISAQNRCJCOW5DLMY.jpg'}}]}],
#        'summary': '5 likes'},
#       'logView': True,
#       'agreeCount': 4,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '4195014',
#        'firstName': 'Eyeless',
#        'lastName': 'M',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/B4TL4W4HNTP5ZQN1.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/4EBo8Y',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 53,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 53,
#     'items': [{'id': '5070ddf2e4b019e66b485219',
#       'name': 'Toronto: Favorite outdoors, chill & art places!',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '9337194',
#        'firstName': 'Krıstófer-Þórır',
#        'lastName': 'D',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/9337194_D6hGippI_Hxrgao2K3M1HjwaIz-LbllvhePHp6foo5ier8pJ4fdlflJun9Xmehit1da2V05PO.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/ny_batterii/list/toronto-favorite-outdoors-chill--art-places',
#       'canonicalUrl': 'https://foursquare.com/ny_batterii/list/toronto-favorite-outdoors-chill--art-places',
#       'createdAt': 1349574130,
#       'updatedAt': 1405611048,
#       'photo': {'id': '53c6da92498e9bf623681170',
#        'createdAt': 1405541010,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/43670176_AwVGPOMJra0VkFPPWcAJHi3TtdRdD1mvSOsDkL7OIYc.jpg',
#        'width': 720,
#        'height': 720,
#        'user': {'id': '43670176',
#         'firstName': 'Ellen',
#         'lastName': 'S',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/NTFP4X5BAMFUSOA1.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 12},
#       'listItems': {'count': 28,
#        'items': [{'id': 'v4ad4c064f964a52065f820e3',
#          'createdAt': 1395077881,
#          'photo': {'id': '53273000498e0a538d359209',
#           'createdAt': 1395077120,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/9337194_6N57TiGzrXwEEH0D4F-G9evxf3KHYN2cA22PDl8p7t0.jpg',
#           'width': 720,
#           'height': 734,
#           'user': {'id': '9337194',
#            'firstName': 'Krıstófer-Þórır',
#            'lastName': 'D',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/9337194_D6hGippI_Hxrgao2K3M1HjwaIz-LbllvhePHp6foo5ier8pJ4fdlflJun9Xmehit1da2V05PO.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '513e5f9ae4b07729cba5bd41',
#       'name': 'Toronto x Where the fun is at',
#       'description': 'Spontaneous dates in Toronto usually include 1) a random city fave venue and 2) an open mind.',
#       'type': 'others',
#       'user': {'id': '5007479',
#        'firstName': 'Angie',
#        'lastName': 'R',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/DRG30JBOOUNT0M5V.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/ngietr/list/toronto-x-where-the-fun-is-at',
#       'canonicalUrl': 'https://foursquare.com/ngietr/list/toronto-x-where-the-fun-is-at',
#       'createdAt': 1363042202,
#       'updatedAt': 1400773635,
#       'photo': {'id': '4f3e684a00394a3349ee0b36',
#        'createdAt': 1329489994,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/DFa4LpXO5RsYIN9Eg30yGSEkoKHwG8mSlom0K8QtMso.jpg',
#        'width': 220,
#        'height': 220,
#        'user': {'id': '311503',
#         'firstName': 'AskMen',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/W12HFINBWKQZJ15Z.jpg'},
#         'type': 'page'},
#        'visibility': 'public'},
#       'followers': {'count': 14},
#       'listItems': {'count': 49,
#        'items': [{'id': 'v4ad4c064f964a52065f820e3',
#          'createdAt': 1400773613,
#          'photo': {'id': '50e6f769e4b06958b1fdf7a6',
#           'createdAt': 1357313897,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/63159_xLOrOT5wltKh0G4gLdw63hExOVU3JgvVET7jDik4NlE.jpg',
#           'width': 612,
#           'height': 612,
#           'user': {'id': '63159',
#            'firstName': 'nik',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/ZIIIPGCR22P0H3R2.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4fccd515e4b0a382cc995589',
#       'name': 'Top art and culture in Toronto',
#       'description': 'Some great places for art and culture in toronto',
#       'type': 'others',
#       'user': {'id': '29328366',
#        'firstName': 'jennifer ford',
#        'lastName': 's',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/C5I4KZGAUKVNAIQJ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/jenniferfordsha/list/top-art-and-culture-in-toronto',
#       'canonicalUrl': 'https://foursquare.com/jenniferfordsha/list/top-art-and-culture-in-toronto',
#       'createdAt': 1338823957,
#       'updatedAt': 1394397025,
#       'photo': {'id': '4fb570d1e4b01f0f6aa9632c',
#        'createdAt': 1337290961,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/e8-IMMyi7ESaNOp9IvUgSc1gVHdiPFukPx3xoopMXtc.jpg',
#        'width': 612,
#        'height': 612,
#        'user': {'id': '767610',
#         'firstName': 'Sean',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/767610-21DJNWT4UO2WJNG4.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 6},
#       'listItems': {'count': 26,
#        'items': [{'id': 'v4ad4c064f964a52065f820e3',
#          'createdAt': 1338824011,
#          'photo': {'id': '4f9027b6e4b0051a3c8c2353',
#           'createdAt': 1334847414,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/viEf9-mOVAVmGkja3aHVyAZd4KTiwgxbfNwqnoxRBRU.jpg',
#           'width': 612,
#           'height': 612,
#           'user': {'id': '9889',
#            'firstName': 'Molly',
#            'lastName': 'P',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/HEV1VHV33AYGVBSF.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '9:00 AM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '1:00 PM–3:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Tue–Wed',
#     'open': [{'renderedTime': '8:00 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '8:00 AM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': []},
#  'bestPhoto': {'id': '50e6f769e4b06958b1fdf7a6',
#   'createdAt': 1357313897,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/63159_xLOrOT5wltKh0G4gLdw63hExOVU3JgvVET7jDik4NlE.jpg',
#   'width': 612,
#   'height': 612,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '50e6f769e4b06958b1fdf7a6',
#    'value': -2568000},
#   'highlightTextColor': {'photoId': '50e6f769e4b06958b1fdf7a6',
#    'value': -16777216},
#   'algoVersion': 3}}

# %%
#Rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.3

# %%
#Art Gallery of Ontario

venue_id = '4ad4c05ef964a520daf620e3' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()

# %%
#Rating
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.2

# %%
#Get the number of tips   
result['response']['venue']['tips']['count']
# Out:
# 200

# %%
#Create URL and send GET request
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad4c05ef964a520daf620e3/tips?client_id=2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX&client_secret=MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ&v=20200201&limit=15'

# %%
#Json
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e59bf31882fc700280e9948'},
#  'response': {'tips': {'count': 200,
#    'items': [{'id': '4f05d2189adf79d87398ecf8',
#      'createdAt': 1325781528,
#      'text': "Did you know that the AGO's spiral staircase, designed by Frank Gehry, is purposefully narrow so that people could bump into each other and fall in love. Ahhh!",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4f05d2189adf79d87398ecf8',
#      'lang': 'en',
#      'likes': {'count': 25,
#       'groups': [{'type': 'others', 'count': 25, 'items': []}],
#       'summary': '25 likes'},
#      'logView': True,
#      'editedAt': 1372872636,
#      'agreeCount': 45,
#      'disagreeCount': 0,
#      'lastVoteText': 'Upvoted Jan 25',
#      'lastUpvoteTimestamp': 1579982967,
#      'todo': {'count': 1},
#      'user': {'id': '13980167',
#       'firstName': 'Art Gallery of Ontario',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/13980167-31YTZ5T0LC4GBK33.gif'},
#       'type': 'page'}}]}}}

# %%
#Get tips and list of associated features
tips = results['response']['tips']['items']
tips
# Out:
# [{'id': '4f05d2189adf79d87398ecf8',
#   'createdAt': 1325781528,
#   'text': "Did you know that the AGO's spiral staircase, designed by Frank Gehry, is purposefully narrow so that people could bump into each other and fall in love. Ahhh!",
#   'type': 'user',
#   'canonicalUrl': 'https://foursquare.com/item/4f05d2189adf79d87398ecf8',
#   'lang': 'en',
#   'likes': {'count': 25,
#    'groups': [{'type': 'others', 'count': 25, 'items': []}],
#    'summary': '25 likes'},
#   'logView': True,
#   'editedAt': 1372872636,
#   'agreeCount': 45,
#   'disagreeCount': 0,
#   'lastVoteText': 'Upvoted Jan 25',
#   'lastUpvoteTimestamp': 1579982967,
#   'todo': {'count': 1},
#   'user': {'id': '13980167',
#    'firstName': 'Art Gallery of Ontario',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/13980167-31YTZ5T0LC4GBK33.gif'},
#    'type': 'page'}}]

# %%
#first tip, dict keys
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'editedAt', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user'])

# %%
tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'editedAt', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user'])

# %%
#Format column width and display all tips
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

##Format column width and display all tips
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# C:\Users\hardo\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                                                               text  \
# 0  Did you know that the AGO's spiral staircase, designed by Frank Gehry, is purposefully narrow so that people could bump into each other and fall in love. Ahhh!
#
#    agreeCount  disagreeCount                        id  \
# 0  45          0              4f05d2189adf79d87398ecf8
#
#            user.firstName  user.lastName  user.gender   user.id
# 0  Art Gallery of Ontario NaN            NaN           13980167

# %%
#User of the last comment

#https://foursquare.com/developers/explore
#https://api.foursquare.com/v2/users/13980167?client_id=2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX&client_secret=MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ&v=20200201
# Out:
# 'https://api.foursquare.com/v2/users/13980167?client_id=2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX&client_secret=MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ&v=20200201&limit=30'

# %%
#Invalidid credentials for users
url = 'https://api.foursquare.com/v2/users/13980167?client_id=2XTXUDPQTGZFAHBYZ1UKI4PNDRO0WYTPVX2BJMYV32ANXOPX&client_secret=MKH4FVRUVQNDC3MAQE350E2ACWGRSL311B5YMMLTXLBQ5CIZ&v=20200201'

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 401,
#   'errorType': 'invalid_auth',
#   'errorDetail': 'Missing oauth_token. See https://developer.foursquare.com/docs/api/configuration/authentication for details.',
#   'requestId': '5e59bfe9be61c9001be381f0'},
#  'response': {}}

# %%
#Get user's tips
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                                   text  \
# 0  Did you know that the AGO's spiral staircase, designed by Frank Gehry, is purposefully narrow so that people could bump into each other and fall in love. Ahhh!
# 1  Situated in the Grange (the oldest part of the Gallery), our Members' Lounge is a great spot to rest your feet. Cosy yet refined and with lovely views of the park.
# 2  The cheese and ham croissants could quite possibly be the best in the city. Just saying...
# 3  From 3pm on weekdays we have a range of exciting free youth classes including DJ lessons and hip-hop dance. Check out our youth Facebook page for more details!
#
#    agreeCount  disagreeCount                        id
# 0  45          0              4f05d2189adf79d87398ecf8
# 1  1           0              4f05c3c299116f05b5e61e4c
# 2  2           0              4f05b9ca46909da7013500ac
# 3  1           0              4f05b8a229c22bbeff0f9e5f

# %%
#Greatest agree counts
#No user data, invalid credentials

#Let's get the venue for the tip with the greatest number of agree counts
tip_id = '4f05d2189adf79d87398ecf8' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])

#Get User's friends
user_friends = json_normalize(user_data['friends']['groups'][0]['items']) #No user data
user_friends
# Out:
# Art Gallery of Ontario
# {'address': '317 Dundas St W', 'crossStreet': 'at Beverley St', 'lat': 43.654002860337386, 'lng': -79.39292172707437, 'labeledLatLngs': [{'label': 'display', 'lat': 43.654002860337386, 'lng': -79.39292172707437}], 'postalCode': 'M5T 1G4', 'cc': 'CA', 'city': 'Toronto', 'state': 'ON', 'country': 'Canada', 'formattedAddress': ['317 Dundas St W (at Beverley St)', 'Toronto ON M5T 1G4', 'Canada']}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-bc7bd58d8eba> in <module>
#      13
#      14 #Get User's friends
# ---> 15 user_friends = json_normalize(user_data['friends']['groups'][0]['items']) #No user data
#      16 user_friends
#
# NameError: name 'user_data' is not defined

# %%
#Explore a location in Toronto

latitude = 43.662852
longitude = -79.396450

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e59c875b57e88001b5e3967'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Toronto',
#   'headerFullLocation': 'Toronto',
#   'headerLocationGranularity': 'city',
#   'totalResults': 241,
#   'suggestedBounds': {'ne': {'lat': 43.68985202700003,
#     'lng': -79.35919667039902},
#    'sw': {'lat': 43.63585197299997, 'lng': -79.43370332960099}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9d206bf964a520e69136e3',
#        'name': "Queen's Park",
#        'location': {'address': 'University Ave.',
#         'crossStreet': 'at Wellesley Ave.',
#         'lat': 43.66394609897775,
#         'lng': -79.39217952520835,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66394609897775,
#           'lng': -79.39217952520835}],
#         'distance': 364,
#         'postalCode': 'M5R 2E8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['University Ave. (at Wellesley Ave.)',
#          'Toronto ON M5R 2E8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9d206bf964a520e69136e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba79cd4f964a52060a239e3',
#        'name': "Philosopher's Walk",
#        'location': {'crossStreet': 'University of Toronto',
#         'lat': 43.666893747498605,
#         'lng': -79.39559698104858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.666893747498605,
#           'lng': -79.39559698104858}],
#         'distance': 455,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba79cd4f964a52060a239e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adf787cf964a520e57a21e3',
#        'name': 'Koerner Hall',
#        'location': {'address': '273 Bloor St. W',
#         'crossStreet': 'at Avenue Rd.',
#         'lat': 43.667983280307865,
#         'lng': -79.3959619437764,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.667983280307865,
#           'lng': -79.3959619437764}],
#         'distance': 572,
#         'postalCode': 'M5S 1W2',
#         'cc': 'CA',
#         'neighborhood': 'University of Toronto',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['273 Bloor St. W (at Avenue Rd.)',
#          'Toronto ON M5S 1W2',
#          'Canada']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adf787cf964a520e57a21e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '527d450111d25050de4ea0d8',
#        'name': 'Rasa',
#        'location': {'address': '196 Robert Street',
#         'lat': 43.662756751275445,
#         'lng': -79.40398803188654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.662756751275445,
#           'lng': -79.40398803188654}],
#         'distance': 607,
#         'postalCode': 'M5S 2K8',
#         'cc': 'CA',
#         'neighborhood': 'Downtown Toronto',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['196 Robert Street',
#          'Toronto ON M5S 2K8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-527d450111d25050de4ea0d8-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a520d9f620e3',
#        'name': 'Royal Ontario Museum',
#        'location': {'address': "100 Queen's Pk",
#         'crossStreet': 'at Bloor St. W.',
#         'lat': 43.668367065616046,
#         'lng': -79.3948129405877,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.668367065616046,
#           'lng': -79.3948129405877}],
#         'distance': 627,
#         'postalCode': 'M5S 2C6',
#         'cc': 'CA',
#         'neighborhood': 'University',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["100 Queen's Pk (at Bloor St. W.)",
#          'Toronto ON M5S 2C6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05ef964a520d9f620e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fce7df0e4b0d498825b14d2',
#        'name': 'ROM Museum Store',
#        'location': {'address': "100 Queen's Park",
#         'crossStreet': 'inside Royal Ontario Museum',
#         'lat': 43.66851433563614,
#         'lng': -79.39487921364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66851433563614,
#           'lng': -79.39487921364}],
#         'distance': 642,
#         'postalCode': 'M5S 2C6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ["100 Queen's Park (inside Royal Ontario Museum)",
#          'Toronto ON M5S 2C6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fce7df0e4b0d498825b14d2-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5707bcb9498e709b544e20b2',
#        'name': "Her Father's Cider Bar + Kitchen",
#        'location': {'address': '119 Harbord Street',
#         'crossStreet': 'at Major St',
#         'lat': 43.66244824890102,
#         'lng': -79.40470324675829,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66244824890102,
#           'lng': -79.40470324675829}],
#         'distance': 666,
#         'postalCode': 'M5S 1G7',
#         'cc': 'CA',
#         'neighborhood': 'Downtown Toronto',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['119 Harbord Street (at Major St)',
#          'Toronto ON M5S 1G7',
#          'Canada']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5707bcb9498e709b544e20b2-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b31677bf964a520530625e3',
#        'name': 'Royal Conservatory of Music',
#        'location': {'address': '273 Bloor St W',
#         'lat': 43.66822758218325,
#         'lng': -79.39631143267306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66822758218325,
#           'lng': -79.39631143267306}],
#         'distance': 598,
#         'postalCode': 'M5S 1W2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['273 Bloor St W',
#          'Toronto ON M5S 1W2',
#          'Canada']},
#        'categories': [{'id': '4f04b10d2fb6e1c99f3db0be',
#          'name': 'Music School',
#          'pluralName': 'Music Schools',
#          'shortName': 'Music School',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b31677bf964a520530625e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df15e3c1f6e818dadf7afc0',
#        'name': 'Fresh on Bloor',
#        'location': {'address': '326 Bloor St. W',
#         'lat': 43.66675488472059,
#         'lng': -79.40349130034014,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66675488472059,
#           'lng': -79.40349130034014}],
#         'distance': 714,
#         'postalCode': 'M5S 1W5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['326 Bloor St. W',
#          'Toronto ON M5S 1W5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df15e3c1f6e818dadf7afc0-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d947c8c1646a35df82237a3',
#        'name': 'The Planet Traveler',
#        'location': {'address': '357 College Street',
#         'lat': 43.657202,
#         'lng': -79.403568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.657202,
#           'lng': -79.403568}],
#         'distance': 850,
#         'postalCode': 'M5T 1S5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['357 College Street',
#          'Toronto ON M5T 1S5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d947c8c1646a35df82237a3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ade455bf964a520837421e3',
#        'name': 'Harbord House',
#        'location': {'address': '150 Harbord St.',
#         'lat': 43.66246595195944,
#         'lng': -79.40541041671369,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66246595195944,
#           'lng': -79.40541041671369}],
#         'distance': 722,
#         'postalCode': 'M5S 1H2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['150 Harbord St.',
#          'Toronto ON M5S 1H2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58019843'}},
#       'referralId': 'e-0-4ade455bf964a520837421e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a520daf620e3',
#        'name': 'Art Gallery of Ontario',
#        'location': {'address': '317 Dundas St W',
#         'crossStreet': 'at Beverley St',
#         'lat': 43.654002860337386,
#         'lng': -79.39292172707437,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.654002860337386,
#           'lng': -79.39292172707437}],
#         'distance': 1025,
#         'postalCode': 'M5T 1G4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['317 Dundas St W (at Beverley St)',
#          'Toronto ON M5T 1G4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33853777'}},
#       'referralId': 'e-0-4ad4c05ef964a520daf620e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5061dbab498ee603149683e5',
#        'name': 'Voodoo Child',
#        'location': {'address': '388 College street',
#         'lat': 43.65695821626081,
#         'lng': -79.40546029795985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65695821626081,
#           'lng': -79.40546029795985}],
#         'distance': 978,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['388 College street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5061dbab498ee603149683e5-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50427a03e4b08d9f5931f593',
#        'name': 'Seven Lives - Tacos y Mariscos',
#        'location': {'address': '69 Kensington Ave',
#         'crossStreet': 'Baldwin St',
#         'lat': 43.65441817160925,
#         'lng': -79.40054467846261,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65441817160925,
#           'lng': -79.40054467846261}],
#         'distance': 995,
#         'postalCode': 'M5T 2L6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['69 Kensington Ave (Baldwin St)',
#          'Toronto ON M5T 2L6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36738371'}},
#       'referralId': 'e-0-50427a03e4b08d9f5931f593-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55820db4498e4abb523622bf',
#        'name': "Otto's Berlin Döner",
#        'location': {'address': '256 Augusta Ave',
#         'crossStreet': 'at Oxford St',
#         'lat': 43.65638733696026,
#         'lng': -79.40278822246442,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65638733696026,
#           'lng': -79.40278822246442}],
#         'distance': 882,
#         'postalCode': 'M5T 2L9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['256 Augusta Ave (at Oxford St)',
#          'Toronto ON M5T 2L9',
#          'Canada']},
#        'categories': [{'id': '5283c7b4e4b094cb91ec88d8',
#          'name': 'Doner Restaurant',
#          'pluralName': 'Doner Restaurants',
#          'shortName': 'Doner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55820db4498e4abb523622bf-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '535163cf498ea10a3b9582b5',
#        'name': 'Blackbird Baking Co',
#        'location': {'address': '172 Baldwin Street',
#         'lat': 43.65476385976386,
#         'lng': -79.40056588367806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65476385976386,
#           'lng': -79.40056588367806}],
#         'distance': 959,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['172 Baldwin Street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '143838823'}},
#       'referralId': 'e-0-535163cf498ea10a3b9582b5-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b116957f964a520087c23e3',
#        'name': 'Kid Icarus',
#        'location': {'address': '205 Augusta Ave.',
#         'crossStreet': 'Denison Square',
#         'lat': 43.653933260442265,
#         'lng': -79.40171859012935,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.653933260442265,
#           'lng': -79.40171859012935}],
#         'distance': 1079,
#         'postalCode': 'M5T 2L4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['205 Augusta Ave. (Denison Square)',
#          'Toronto ON M5T 2L4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d127951735',
#          'name': 'Arts & Crafts Store',
#          'pluralName': 'Arts & Crafts Stores',
#          'shortName': 'Arts & Crafts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '55521198'}},
#       'referralId': 'e-0-4b116957f964a520087c23e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b240652f964a5205a5f24e3',
#        'name': 'Indigo',
#        'location': {'address': '55 Bloor St. W',
#         'crossStreet': 'at Bay St.',
#         'lat': 43.66906505288213,
#         'lng': -79.38905744719285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66906505288213,
#           'lng': -79.38905744719285}],
#         'distance': 912,
#         'postalCode': 'M4W 1A5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Bloor St. W (at Bay St.)',
#          'Toronto ON M4W 1A5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b240652f964a5205a5f24e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51438b33e4b0a40e33fe5e77',
#        'name': "Jimmy's Coffee",
#        'location': {'address': '191 Baldwin St',
#         'crossStreet': 'Kensington Market',
#         'lat': 43.65449315540114,
#         'lng': -79.40131090393002,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65449315540114,
#           'lng': -79.40131090393002}],
#         'distance': 1009,
#         'cc': 'CA',
#         'neighborhood': 'Kensington Market',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['191 Baldwin St (Kensington Market)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51438b33e4b0a40e33fe5e77-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af30f13f964a52030ea21e3',
#        'name': 'Trattoria Nervosa',
#        'location': {'address': '75 Yorkville Ave.',
#         'crossStreet': 'at Bellair St.',
#         'lat': 43.67101871082308,
#         'lng': -79.39108133032904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67101871082308,
#           'lng': -79.39108133032904}],
#         'distance': 1006,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['75 Yorkville Ave. (at Bellair St.)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af30f13f964a52030ea21e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '554ea8bd498efa064ec03031',
#        'name': 'Paramount Fine Foods',
#        'location': {'address': '1250 Bay Street',
#         'lat': 43.67067671443592,
#         'lng': -79.38986486034777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67067671443592,
#           'lng': -79.38986486034777}],
#         'distance': 1019,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1250 Bay Street', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-554ea8bd498efa064ec03031-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59ecf741da2e006b9e11a3d3',
#        'name': 'The Alley',
#        'location': {'address': '5 St Joseph Street',
#         'lat': 43.66592244798498,
#         'lng': -79.38556672752236,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66592244798498,
#           'lng': -79.38556672752236}],
#         'distance': 940,
#         'postalCode': 'M4Y 1Z3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['5 St Joseph Street',
#          'Toronto ON M4Y 1Z3',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59ecf741da2e006b9e11a3d3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c5dd8d498e25dee9f19457',
#        'name': 'Isshin Ramen 一心',
#        'location': {'address': '421 College St',
#         'crossStreet': 'at Bathurst St',
#         'lat': 43.65651655724417,
#         'lng': -79.40694540739058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65651655724417,
#           'lng': -79.40694540739058}],
#         'distance': 1100,
#         'postalCode': 'M5T 1T1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['421 College St (at Bathurst St)',
#          'Toronto ON M5T 1T1',
#          'Canada']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c5dd8d498e25dee9f19457-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adccb27f964a520e02f21e3',
#        'name': 'Essence of Life Organics',
#        'location': {'address': '50 Kensington Avenue',
#         'crossStreet': 'St. Andrew St.',
#         'lat': 43.65411067840614,
#         'lng': -79.4004308758787,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65411067840614,
#           'lng': -79.4004308758787}],
#         'distance': 1024,
#         'postalCode': 'M5T 2K1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['50 Kensington Avenue (St. Andrew St.)',
#          'Toronto ON M5T 2K1',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b45',
#          'name': 'Organic Grocery',
#          'pluralName': 'Organic Groceries',
#          'shortName': 'Organic Grocery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adccb27f964a520e02f21e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2d934e59c423002c0c6db6',
#        'name': 'Eataly',
#        'location': {'address': '55 Bloor St W',
#         'crossStreet': 'at Bay St',
#         'lat': 43.66975356278464,
#         'lng': -79.3887197971344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66975356278464,
#           'lng': -79.3887197971344}],
#         'distance': 988,
#         'postalCode': 'M4W 1A5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Bloor St W (at Bay St)',
#          'Toronto ON M4W 1A5',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1f5941735',
#          'name': 'Gourmet Shop',
#          'pluralName': 'Gourmet Shops',
#          'shortName': 'Gourmet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_gourmet_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2d934e59c423002c0c6db6-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a81ae339deb7d369fa7f146',
#        'name': 'Hailed Coffee',
#        'location': {'address': '44 Gerrard St W',
#         'crossStreet': 'Yonge St',
#         'lat': 43.65883296982352,
#         'lng': -79.38368351986598,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65883296982352,
#           'lng': -79.38368351986598}],
#         'distance': 1121,
#         'postalCode': 'M5G',
#         'cc': 'CA',
#         'neighborhood': 'College Park',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['44 Gerrard St W (Yonge St)',
#          'Toronto ON M5G',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a81ae339deb7d369fa7f146-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aea0fc3b9b37b002c30ab00',
#        'name': 'Fuwa Fuwa Japanese Pancakes',
#        'location': {'address': '408 Bloor St. West',
#         'lat': 43.66587984725407,
#         'lng': -79.40783968911445,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.66587984725407,
#           'lng': -79.40783968911445}],
#         'distance': 977,
#         'postalCode': 'M5S 2N5',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['408 Bloor St. West',
#          'Toronto ON M5S 2N5',
#          'Canada']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4e2',
#          'name': 'Pastry Shop',
#          'pluralName': 'Pastry Shops',
#          'shortName': 'Pastry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aea0fc3b9b37b002c30ab00-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537d4d6d498ec171ba22e7fe',
#        'name': "Jimmy's Coffee",
#        'location': {'address': '82 Gerrard Street W',
#         'crossStreet': 'Gerrard & LaPlante',
#         'lat': 43.65842123574496,
#         'lng': -79.38561319551111,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65842123574496,
#           'lng': -79.38561319551111}],
#         'distance': 1002,
#         'postalCode': 'M5G 1Z4',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['82 Gerrard Street W (Gerrard & LaPlante)',
#          'Toronto ON M5G 1Z4',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537d4d6d498ec171ba22e7fe-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c063f964a52052f820e3',
#        'name': 'Whole Foods Market',
#        'location': {'address': '87 Avenue Road',
#         'crossStreet': 'Davenport Rd',
#         'lat': 43.672005429317515,
#         'lng': -79.3948317514291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.672005429317515,
#           'lng': -79.3948317514291}],
#         'distance': 1027,
#         'postalCode': 'M5R 3R9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['87 Avenue Road (Davenport Rd)',
#          'Toronto ON M5R 3R9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c063f964a52052f820e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c062f964a520b9f720e3',
#        'name': 'Hot Docs Ted Rogers Cinema',
#        'location': {'address': '506 Bloor St. W',
#         'crossStreet': 'btwn Bathurst St. & Albany Ave.',
#         'lat': 43.665499199156656,
#         'lng': -79.4103125084796,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.665499199156656,
#           'lng': -79.4103125084796}],
#         'distance': 1154,
#         'postalCode': 'M5S 1Y3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['506 Bloor St. W (btwn Bathurst St. & Albany Ave.)',
#          'Toronto ON M5S 1Y3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'events': {'count': 2, 'summary': '2 movies'},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c062f964a520b9f720e3-29'}]}]}}

# %%
#First Item
import requests
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b9d206bf964a520e69136e3',
#   'name': "Queen's Park",
#   'location': {'address': 'University Ave.',
#    'crossStreet': 'at Wellesley Ave.',
#    'lat': 43.66394609897775,
#    'lng': -79.39217952520835,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.66394609897775,
#      'lng': -79.39217952520835}],
#    'distance': 364,
#    'postalCode': 'M5R 2E8',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['University Ave. (at Wellesley Ave.)',
#     'Toronto ON M5R 2E8',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d163941735',
#     'name': 'Park',
#     'pluralName': 'Parks',
#     'shortName': 'Park',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4b9d206bf964a520e69136e3-0'}

# %%
#Process JSON and convert it to a clean dataframe
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                                name                     categories  \
# 0  Queen's Park                      Park
# 1  Philosopher's Walk                Park
# 2  Koerner Hall                      Concert Hall
# 3  Rasa                              Restaurant
# 4  Royal Ontario Museum              Museum
# 5  ROM Museum Store                  Gift Shop
# 6  Her Father's Cider Bar + Kitchen  Beer Bar
# 7  Royal Conservatory of Music       Music School
# 8  Fresh on Bloor                    Vegetarian / Vegan Restaurant
# 9  The Planet Traveler               Hostel
#
#               address                  crossStreet        lat        lng  \
# 0  University Ave.     at Wellesley Ave.            43.663946 -79.392180
# 1  NaN                 University of Toronto        43.666894 -79.395597
# 2  273 Bloor St. W     at Avenue Rd.                43.667983 -79.395962
# 3  196 Robert Street   NaN                          43.662757 -79.403988
# 4  100 Queen's Pk      at Bloor St. W.              43.668367 -79.394813
# 5  100 Queen's Park    inside Royal Ontario Museum  43.668514 -79.394879
# 6  119 Harbord Street  at Major St                  43.662448 -79.404703
# 7  273 Bloor St W      NaN                          43.668228 -79.396311
# 8  326 Bloor St. W     NaN                          43.666755 -79.403491
# 9  357 College Street  NaN                          43.657202 -79.403568
#
#                                                                  labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 43.66394609897775, 'lng': -79.39217952520835}]
# 1  [{'label': 'display', 'lat': 43.666893747498605, 'lng': -79.39559698104858}]
# 2  [{'label': 'display', 'lat': 43.667983280307865, 'lng': -79.3959619437764}]
# 3  [{'label': 'display', 'lat': 43.662756751275445, 'lng': -79.40398803188654}]
# 4  [{'label': 'display', 'lat': 43.668367065616046, 'lng': -79.3948129405877}]
# 5  [{'label': 'display', 'lat': 43.66851433563614, 'lng': -79.39487921364}]
# 6  [{'label': 'display', 'lat': 43.66244824890102, 'lng': -79.40470324675829}]
# 7  [{'label': 'display', 'lat': 43.66822758218325, 'lng': -79.39631143267306}]
# 8  [{'label': 'display', 'lat': 43.66675488472059, 'lng': -79.40349130034014}]
# 9  [{'label': 'display', 'lat': 43.657202, 'lng': -79.403568}]
#
#    distance postalCode  cc     city state country  \
# 0  364       M5R 2E8    CA  Toronto  ON    Canada
# 1  455       NaN        CA  Toronto  ON    Canada
# 2  572       M5S 1W2    CA  Toronto  ON    Canada
# 3  607       M5S 2K8    CA  Toronto  ON    Canada
# 4  627       M5S 2C6    CA  Toronto  ON    Canada
# 5  642       M5S 2C6    CA  Toronto  ON    Canada
# 6  666       M5S 1G7    CA  Toronto  ON    Canada
# 7  598       M5S 1W2    CA  Toronto  ON    Canada
# 8  714       M5S 1W5    CA  Toronto  ON    Canada
# 9  850       M5T 1S5    CA  Toronto  ON    Canada
#
#                                                                formattedAddress  \
# 0  [University Ave. (at Wellesley Ave.), Toronto ON M5R 2E8, Canada]
# 1  [Toronto ON, Canada]
# 2  [273 Bloor St. W (at Avenue Rd.), Toronto ON M5S 1W2, Canada]
# 3  [196 Robert Street, Toronto ON M5S 2K8, Canada]
# 4  [100 Queen's Pk (at Bloor St. W.), Toronto ON M5S 2C6, Canada]
# 5  [100 Queen's Park (inside Royal Ontario Museum), Toronto ON M5S 2C6, Canada]
# 6  [119 Harbord Street (at Major St), Toronto ON M5S 1G7, Canada]
# 7  [273 Bloor St W, Toronto ON M5S 1W2, Canada]
# 8  [326 Bloor St. W, Toronto ON M5S 1W5, Canada]
# 9  [357 College Street, Toronto ON M5T 1S5, Canada]
#
#             neighborhood                        id
# 0  NaN                    4b9d206bf964a520e69136e3
# 1  NaN                    4ba79cd4f964a52060a239e3
# 2  University of Toronto  4adf787cf964a520e57a21e3
# 3  Downtown Toronto       527d450111d25050de4ea0d8
# 4  University             4ad4c05ef964a520d9f620e3
# 5  NaN                    4fce7df0e4b0d498825b14d2
# 6  Downtown Toronto       5707bcb9498e709b544e20b2
# 7  NaN                    4b31677bf964a520530625e3
# 8  NaN                    4df15e3c1f6e818dadf7afc0
# 9  NaN                    4d947c8c1646a35df82237a3

# %%
#Visualization

venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Location',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Explore trading Venues

# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e59c75c40a7ea001b1fa76f'},
#  'response': {'venues': []}}

# %%
#Check if venues
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
    
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
#Visualization
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)
        
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'
